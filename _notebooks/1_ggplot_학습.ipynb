# %% [markdown]
# # (R) ggplot

# %% [markdown]
# ## ggplot

# %%
library('tidyverse')

# %% [markdown]
# #### color

# %%
ggplot(data = mpg) + geom_point(mapping = aes(x= displ, y= hwy, color = class))
# Out:
# plot without title

# %%
ggplot(data = mpg) + geom_point(mapping = aes(x= displ, y= hwy, size = class))
# Out:
# Warning message:
# “Using size for a discrete variable is not advised.”
# plot without title

# %%
ggplot(data = mpg) + 
geom_point(mapping = aes(x= displ, y = hwy, alpha = class))
# Out:
# Warning message:
# “Using alpha for a discrete variable is not advised.”
# plot without title

# %%
ggplot(data = mpg) + 
geom_point(mapping = aes(x= displ, y = hwy, shape = class))
# Out:
# Warning message:
# “The shape palette can deal with a maximum of 6 discrete values because
# more than 6 becomes difficult to discriminate; you have 7. Consider
# specifying shapes manually if you must have them.”
# Warning message:
# “Removed 62 rows containing missing values (geom_point).”
# plot without title

# %%
ggplot(data = mpg) +
geom_point(mapping = aes(x= displ, y= hwy), color = 'blue')
# Out:
# plot without title

# %% [markdown]
# #### facet_wrap

# %% [markdown]
# `-` 차 종류(class)에 따라 나눈 모습
# nrow = 줄 개수

# %%
ggplot(data = mpg) +
geom_point(mapping = aes(x=displ, y=hwy)) +
facet_wrap(~ class, nrow = 3)
# Out:
# plot without title

# %%
ggplot(data = mpg) +
geom_point(mapping = aes(x= displ, y= hwy)) +
facet_grid(drv ~ cyl)
# Out:
# plot without title

# %%
#### shape icon 번호

# ![Image](IMG_0393.jpg)

# %% [markdown]
# 깃헙 이미지는 올리법 따로 있음 그거 이용

# %%
ggplot(data = mpg) +
geom_point(mapping = aes(x= displ, y= hwy),shape =23)
# Out:
# plot without title

# %% [markdown]
# #### facet_grid
# facet grid에 적은 항목들의 결과 plot 보여줌

# %%
ggplot(data = mpg) +
geom_point(mapping = aes(x= displ, y =hwy)) +
facet_grid(drv ~ cyl)
# Out:
# plot without title

# %%
mpg %>% head
# Out:
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact

# %%
mpg$drv %>% unique()
# Out:
# [1] "f" "4" "r"

# %%
mpg$cyl %>% unique()
# Out:
# [1] 4 6 8 5

# %% [markdown]
# 열이나 행으로 면분할 하고싶지 않다면 변수이름 대신 . 사용

# %%
ggplot(data = mpg) +
geom_point(mapping = aes(x= displ, y =hwy)) +
facet_grid(. ~ cyl)
# Out:
# plot without title

# %% [markdown]
# cyl에 대한 내용만 나옴

# %%
ggplot(data = mpg) +
geom_point(mapping = aes(x= displ, y = hwy))
# Out:
# plot without title

# %% [markdown]
# #### geom_smooth

# %%
ggplot(data = mpg)+
geom_smooth(mapping = aes(x=displ, y= hwy))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %% [markdown]
# 데이터에 적합된 평활선

# %% [markdown]
# line자체의 shape은 선택 불가지만
# line type 선택 해줄 수 있음

# %%
ggplot(data = mpg)+
geom_smooth(mapping = aes(x=displ, y=hwy, linetype = drv))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %% [markdown]
# 색깔 입히기 가능

# %%
ggplot(data = mpg)+
geom_smooth(mapping = aes(x=displ, y=hwy, group = drv))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(data = mpg)+
geom_smooth(mapping = aes(x=displ, y=hwy, color = drv))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %% [markdown]
# 다 합쳐서 그리기

# %%
ggplot(data = mpg)+ geom_point(mapping = aes(x=displ, y=hwy,color = drv))+
geom_smooth(mapping = aes(x=displ, y=hwy, color = drv, linetype = drv))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %% [markdown]
# #### 코드 중복 피하기
# ggplot안에 mapping 해 놓으면 다음번에 안써도 된다

# %%
ggplot(data = mpg, mapping = aes(x= displ, y=hwy)) +
geom_point() +
geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %% [markdown]
# mapping 해놓고 옵션추가 하고 싶다면 해당 geom에 가서 그 부분만 mapping하고 옵션주면 됨.

# %%
ggplot(data = mpg, mapping = aes(x= displ, y=hwy)) +
geom_point(mapping = aes(color = class)) +
geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %% [markdown]
# #### filter 사용

# %% [markdown]
# 해당 레이어에 한해서만 smooth 하기위해 `filter` 사용
# `se` = FALSE하면 그림자 꺼짐

# %%
ggplot(data = mpg, mapping = aes(x= displ, y=hwy)) +
geom_point(mapping = aes(color = class)) +
geom_smooth(
data = filter(mpg, class == 'subcompact'),
    se= FALSE
    )
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(data = diamonds) +
geom_bar(mapping = aes(x= cut))
# Out:
# plot without title

# %%
ggplot(data = diamonds)+
stat_count(mapping = aes(x=cut))
# Out:
# plot without title

# %% [markdown]
# 이것을 보면 geom_bar의 y축의 default값이 stat_count임을 알 수 있다
# 이 stat을 다른 값을 주면 y축 종류를 바꿀 수 있음

# %%
demo <- tribble(
    ~cut, ~freq,
    "Fair", 1610,
    "Good", 4906,
    "Very Good", 12082,
    "Premium", 13791,
    "Ideal", 21551
    )

# %%
demo
# Out:
#   cut       freq
# 1 Fair       1610
# 2 Good       4906
# 3 Very Good 12082
# 4 Premium   13791
# 5 Ideal     21551

# %%
ggplot(data = demo) +
geom_bar(mapping = aes(x= cut,y=freq), stat = 'identity')
# Out:
# plot without title

# %% [markdown]
# 비율로 표시하기

# %%
ggplot(data = diamonds) +
geom_bar(
    mapping = aes(x = cut, y = stat(prop), group =1)
    )
# Out:
# plot without title

# %% [markdown]
# stat_summary로 표현

# %%
ggplot(data = diamonds) +
stat_summary(
    mapping = aes(x = cut, y= depth),
    fun.ymin = min,
    fun.ymax = max,
    fun.y = median
    )
# Out:
# Warning message:
# “`fun.y` is deprecated. Use `fun` instead.”
# Warning message:
# “`fun.ymin` is deprecated. Use `fun.min` instead.”
# Warning message:
# “`fun.ymax` is deprecated. Use `fun.max` instead.”
# plot without title

# %% [markdown]
# `geom_bar`에서 `color` 사용시 막대그래프의 테두리 색 선택
# `geom_bar`에서 `fill` 사용시 막대그래프 자체 색 선택

# %%
ggplot(data = diamonds) +
geom_bar(mapping = aes(x= cut, color = cut))
ggplot(data = diamonds) +
geom_bar(mapping = aes(x= cut, fill = cut))
# Out:
# plot without title
# plot without title

# %% [markdown]
# `-` 다른 변수 추가해서 각각 얼마나 차지하는지 보이기

# %%
ggplot(data = diamonds) +
geom_bar(mapping = aes(x= cut, fill = clarity))
# Out:
# plot without title

# %%
diamonds$clarity %>% unique
# Out:
# [1] SI2  SI1  VS1  VS2  VVS2 VVS1 I1   IF
# Levels: I1 < SI2 < SI1 < VS2 < VS1 < VVS2 < VVS1 < IF

# %% [markdown]
# `position = 'identity'` : 각 객체를 그래프 문맥에 해당되는 곳에 정확히 배치한다.
# 다만, 막대그래프에서는 그리 유용하지 않음

# %%
ggplot(
    data = diamonds,
    mapping = aes(x = cut, fill = clarity)
    )+
geom_bar(alpha = 0.3, position = 'identity')
# Out:
# plot without title

# %% [markdown]
# 테두리만 색입히고 막대를 빈공간으로 만드는 것도 가능

# %%
ggplot(
    data = diamonds,
    mapping = aes(x = cut, color = clarity)
    )+
geom_bar(fill = NA, position = 'identity')
# Out:
# plot without title

# %% [markdown]
# `position = 'fill'` : 누적 막대인데 막대 높이를 동일하게 맞춤
# 비율 비교에 용이

# %%
ggplot(data = diamonds) +
geom_bar(
    mapping = aes(x =cut, fill = clarity),
    position = 'fill'
    )
# Out:
# plot without title

# %% [markdown]
# `position = 'dodge'` : 옆으로 쌓기
# 개별 값들의 비교 용이

# %%
ggplot(data = diamonds) +
geom_bar(
    mapping = aes(x =cut, fill = clarity),
    position = 'dodge'
    )
# Out:
# plot without title

# %% [markdown]
# `position = 'jitter'` : 중복된 값 진하게 표시

# %%
ggplot(data = mpg) +
geom_point(
    mapping = aes(x =displ, y=hwy),
    position = 'jitter'
    )
# Out:
# plot without title

# %% [markdown]
# `coord_flip()` : x축 y축 변경

# %%
ggplot(data = mpg, mapping = aes(x = class, y= hwy)) +
geom_boxplot()
ggplot(data = mpg, mapping = aes(x = class, y= hwy)) + 
geom_boxplot() +
coord_flip()
# Out:
# plot without title
# plot without title

# %% [markdown]
# `maps` : 위도, 경도 가져오는 library

# %%
library('maps')
# Out:
# 다음의 패키지를 부착합니다: ‘maps’
#
#
# The following object is masked from ‘package:purrr’:
#
#     map

# %%
nz <- map_data('nz')

# %%
nz %>% head
# Out:
#   long     lat       group order region        subregion
# 1 172.7433 -34.44215 1     1     North.Island  NA
# 2 172.7983 -34.45562 1     2     North.Island  NA
# 3 172.8528 -34.44846 1     3     North.Island  NA
# 4 172.8986 -34.41786 1     4     North.Island  NA
# 5 172.9593 -34.42503 1     5     North.Island  NA
# 6 173.0184 -34.39895 1     6     North.Island  NA

# %%
ggplot(nz, aes(long, lat, group = group)) +
geom_polygon(fill = 'white', color = 'black')
# Out:
# plot without title

# %% [markdown]
# `coord_quickmap()` : 지도에 맞게 가로세로 비율 설정
# 공간 데이터 plot에서 중요

# %%
ggplot(nz, aes(long, lat, group = group)) + 
geom_polygon(fill = 'white', color = 'black') +
coord_quickmap()
# Out:
# plot without title

# %% [markdown]
# `labs` : NULL하면 x축이나 y축 이름 안보이게 함
# `theme(aspect.ratio)` : 1이면 정사각형 모양, 그 이상은 세로 길어짐, 이하는 가로가 길어짐
# `width` : 막대 뚱뚱한 정도
# `show.legend` : 범주 표기 여부

# %%
bar <- ggplot(data = diamonds) +
geom_bar(
    mapping = aes(x = cut, fill = cut),
    show.legend = FALSE,
    width = 1
    ) +
theme(aspect.ratio = 1)+
labs(x = NULL, y = NULL)

bar + coord_flip()
# Out:
# plot without title

# %% [markdown]
# `coord_polar()` : pie 차트로 변경

# %%
bar + coord_polar()
# Out:
# plot without title
